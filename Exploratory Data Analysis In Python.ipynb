# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_columns',55)

# %%
#Getting Data
df = pd.read_csv('public_150k_plus_220930.csv')

# %%
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0           NaN  29150-9662     12/18/2020  Paid in Full    24
# 1           NaN  29420-9000     09/28/2021  Paid in Full    24
# 2           NaN  98112-2922     03/17/2021  Paid in Full    24
# 3           NaN  92407-1740     10/16/2021  Paid in Full    24
# 4           NaN         NaN     08/17/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 0                    100              769358.78              769358.78
# 1                    100              736927.79              736927.79
# 2                    100              691355.00              691355.00
# 3                    100              499871.00              499871.00
# 4                    100              367437.00              367437.00
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 0                0.0           NaN                      19248
# 1                0.0           NaN                      19248
# 2                0.0           NaN                       9551
# 3                0.0           NaN                       9551
# 4                0.0           NaN                      57328
#
#                      ServicingLenderName   ServicingLenderAddress  \
# 0                           Synovus Bank            1148 Broadway
# 1                           Synovus Bank            1148 Broadway
# 2  Bank of America, National Association  100 N Tryon St, Ste 170
# 3  Bank of America, National Association  100 N Tryon St, Ste 170
# 4           The Huntington National Bank            17 S High St.
#
#   ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 0            COLUMBUS                   GA         31901-2429
# 1            COLUMBUS                   GA         31901-2429
# 2           CHARLOTTE                   NC         28202-4024
# 3           CHARLOTTE                   NC         28202-4024
# 4            COLUMBUS                   OH         43215-3413
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 0                   U                N            N
# 1                   U                Y            Y
# 2                   U                N            N
# 3                   U                N            N
# 4                   U                N            N
#
#               BusinessAgeDescription       ProjectCity ProjectCountyName  \
# 0  Existing or more than 2 years old            Sumter            SUMTER
# 1  Existing or more than 2 years old  North Charleston        CHARLESTON
# 2    New Business or 2 years or less           SEATTLE              KING
# 3    New Business or 2 years or less    SAN BERNARDINO    SAN BERNARDINO
# 4                         Unanswered               NaN               NaN
#
#   ProjectState  ProjectZip     CD  JobsReported  NAICSCode  \
# 0           SC  29150-9662  SC-05          62.0   325510.0
# 1           SC  29420-9000  SC-06          73.0   561730.0
# 2           WA  98112-2922  WA-07          75.0        NaN
# 3           CA  92407-1740  CA-08          21.0   236115.0
# 4          NaN         NaN    NaN          25.0   484210.0
#
#                                Race               Ethnicity  \
# 0                        Unanswered       Unknown/NotStated
# 1                             White       Unknown/NotStated
# 2                        Unanswered       Unknown/NotStated
# 3  American Indian or Alaska Native  Not Hispanic or Latino
# 4                        Unanswered       Unknown/NotStated
#
#    UTILITIES_PROCEED  PAYROLL_PROCEED  MORTGAGE_INTEREST_PROCEED  \
# 0                NaN        769358.78                        NaN
# 1                NaN        736927.79                        NaN
# 2                NaN        691355.00                        NaN
# 3                NaN        499871.00                        NaN
# 4                NaN        367437.00                        NaN
#
#    RENT_PROCEED  REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  \
# 0           NaN                     NaN                  NaN
# 1           NaN                     NaN                  NaN
# 2           NaN                     NaN                  NaN
# 3           NaN                     NaN                  NaN
# 4           NaN                     NaN                  NaN
#
#    DEBT_INTEREST_PROCEED             BusinessType  \
# 0                    NaN              Corporation
# 1                    NaN      Sole Proprietorship
# 2                    NaN  Non-Profit Organization
# 3                    NaN              Corporation
# 4                    NaN                      NaN
#
#    OriginatingLenderLocationID                      OriginatingLender  \
# 0                        19248                           Synovus Bank
# 1                        19248                           Synovus Bank
# 2                         9551  Bank of America, National Association
# 3                         9551  Bank of America, National Association
# 4                        57328           The Huntington National Bank
#
#   OriginatingLenderCity OriginatingLenderState      Gender      Veteran  \
# 0              COLUMBUS                     GA  Unanswered   Unanswered
# 1              COLUMBUS                     GA  Male Owned  Non-Veteran
# 2             CHARLOTTE                     NC  Unanswered   Unanswered
# 3             CHARLOTTE                     NC  Male Owned  Non-Veteran
# 4              COLUMBUS                     OH  Unanswered   Unanswered
#
#   NonProfit  ForgivenessAmount ForgivenessDate
# 0       NaN          773553.37      11/20/2020
# 1       NaN          746336.24      08/12/2021
# 2         Y          696677.49      02/10/2021
# 3       NaN          395264.11      09/10/2021
# 4       NaN          370819.35      04/08/2021

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 968531 entries, 0 to 968530
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   968531 non-null  int64
#  1   DateApproved                 968531 non-null  object
#  2   SBAOfficeCode                968531 non-null  int64
#  3   ProcessingMethod             968531 non-null  object
#  4   BorrowerName                 968527 non-null  object
#  5   BorrowerAddress              968517 non-null  object
#  6   BorrowerCity                 968519 non-null  object
#  7   BorrowerState                968518 non-null  object
#  8   BorrowerZip                  968518 non-null  object
#  9   LoanStatusDate               923250 non-null  object
#  10  LoanStatus                   968531 non-null  object
#  11  Term                         968531 non-null  int64
#  12  SBAGuarantyPercentage        968531 non-null  int64
#  13  InitialApprovalAmount        968531 non-null  float64
#  14  CurrentApprovalAmount        968531 non-null  float64
#  15  UndisbursedAmount            968481 non-null  float64
#  16  FranchiseName                35405 non-null   object
#  17  ServicingLenderLocationID    968531 non-null  int64
#  18  ServicingLenderName          968531 non-null  object
#  19  ServicingLenderAddress       968531 non-null  object
#  20  ServicingLenderCity          968531 non-null  object
#  21  ServicingLenderState         968531 non-null  object
#  22  ServicingLenderZip           968531 non-null  object
#  23  RuralUrbanIndicator          968531 non-null  object
#  24  HubzoneIndicator             968531 non-null  object
#  25  LMIIndicator                 968531 non-null  object
#  26  BusinessAgeDescription       968530 non-null  object
#  27  ProjectCity                  968518 non-null  object
#  28  ProjectCountyName            968474 non-null  object
#  29  ProjectState                 968522 non-null  object
#  30  ProjectZip                   968517 non-null  object
#  31  CD                           968485 non-null  object
#  32  JobsReported                 968530 non-null  float64
#  33  NAICSCode                    961903 non-null  float64
#  34  Race                         968531 non-null  object
#  35  Ethnicity                    968531 non-null  object
#  36  UTILITIES_PROCEED            339383 non-null  float64
#  37  PAYROLL_PROCEED              966699 non-null  float64
#  38  MORTGAGE_INTEREST_PROCEED    46192 non-null   float64
#  39  RENT_PROCEED                 99538 non-null   float64
#  40  REFINANCE_EIDL_PROCEED       22877 non-null   float64
#  41  HEALTH_CARE_PROCEED          57449 non-null   float64
#  42  DEBT_INTEREST_PROCEED        31724 non-null   float64
#  43  BusinessType                 967809 non-null  object
#  44  OriginatingLenderLocationID  968531 non-null  int64
#  45  OriginatingLender            968531 non-null  object
#  46  OriginatingLenderCity        968531 non-null  object
#  47  OriginatingLenderState       968531 non-null  object
#  48  Gender                       968531 non-null  object
#  49  Veteran                      968531 non-null  object
#  50  NonProfit                    59341 non-null   object
#  51  ForgivenessAmount            933908 non-null  float64
#  52  ForgivenessDate              933908 non-null  object
# dtypes: float64(13), int64(6), object(34)
# memory usage: 391.6+ MB

# %%
#checking for nulls
df.isnull().sum()
# Out:
# LoanNumber                          0
# DateApproved                        0
# SBAOfficeCode                       0
# ProcessingMethod                    0
# BorrowerName                        4
# BorrowerAddress                    14
# BorrowerCity                       12
# BorrowerState                      13
# BorrowerZip                        13
# LoanStatusDate                  45281
# LoanStatus                          0
# Term                                0
# SBAGuarantyPercentage               0
# InitialApprovalAmount               0
# CurrentApprovalAmount               0
# UndisbursedAmount                  50
# FranchiseName                  933126
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# ServicingLenderAddress              0
# ServicingLenderCity                 0
# ServicingLenderState                0
# ServicingLenderZip                  0
# RuralUrbanIndicator                 0
# HubzoneIndicator                    0
# LMIIndicator                        0
# BusinessAgeDescription              1
# ProjectCity                        13
# ProjectCountyName                  57
# ProjectState                        9
# ProjectZip                         14
# CD                                 46
# JobsReported                        1
# NAICSCode                        6628
# Race                                0
# Ethnicity                           0
# UTILITIES_PROCEED              629148
# PAYROLL_PROCEED                  1832
# MORTGAGE_INTEREST_PROCEED      922339
# RENT_PROCEED                   868993
# REFINANCE_EIDL_PROCEED         945654
# HEALTH_CARE_PROCEED            911082
# DEBT_INTEREST_PROCEED          936807
# BusinessType                      722
# OriginatingLenderLocationID         0
# OriginatingLender                   0
# OriginatingLenderCity               0
# OriginatingLenderState              0
# Gender                              0
# Veteran                             0
# NonProfit                      909190
# ForgivenessAmount               34623
# ForgivenessDate                 34623
# dtype: int64

# %%
df = df.loc[df['BorrowerName'].notnull()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 968527 entries, 0 to 968530
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   968527 non-null  int64
#  1   DateApproved                 968527 non-null  object
#  2   SBAOfficeCode                968527 non-null  int64
#  3   ProcessingMethod             968527 non-null  object
#  4   BorrowerName                 968527 non-null  object
#  5   BorrowerAddress              968513 non-null  object
#  6   BorrowerCity                 968515 non-null  object
#  7   BorrowerState                968514 non-null  object
#  8   BorrowerZip                  968514 non-null  object
#  9   LoanStatusDate               923246 non-null  object
#  10  LoanStatus                   968527 non-null  object
#  11  Term                         968527 non-null  int64
#  12  SBAGuarantyPercentage        968527 non-null  int64
#  13  InitialApprovalAmount        968527 non-null  float64
#  14  CurrentApprovalAmount        968527 non-null  float64
#  15  UndisbursedAmount            968477 non-null  float64
#  16  FranchiseName                35405 non-null   object
#  17  ServicingLenderLocationID    968527 non-null  int64
#  18  ServicingLenderName          968527 non-null  object
#  19  ServicingLenderAddress       968527 non-null  object
#  20  ServicingLenderCity          968527 non-null  object
#  21  ServicingLenderState         968527 non-null  object
#  22  ServicingLenderZip           968527 non-null  object
#  23  RuralUrbanIndicator          968527 non-null  object
#  24  HubzoneIndicator             968527 non-null  object
#  25  LMIIndicator                 968527 non-null  object
#  26  BusinessAgeDescription       968526 non-null  object
#  27  ProjectCity                  968514 non-null  object
#  28  ProjectCountyName            968470 non-null  object
#  29  ProjectState                 968518 non-null  object
#  30  ProjectZip                   968513 non-null  object
#  31  CD                           968481 non-null  object
#  32  JobsReported                 968526 non-null  float64
#  33  NAICSCode                    961899 non-null  float64
#  34  Race                         968527 non-null  object
#  35  Ethnicity                    968527 non-null  object
#  36  UTILITIES_PROCEED            339379 non-null  float64
#  37  PAYROLL_PROCEED              966695 non-null  float64
#  38  MORTGAGE_INTEREST_PROCEED    46192 non-null   float64
#  39  RENT_PROCEED                 99538 non-null   float64
#  40  REFINANCE_EIDL_PROCEED       22877 non-null   float64
#  41  HEALTH_CARE_PROCEED          57449 non-null   float64
#  42  DEBT_INTEREST_PROCEED        31724 non-null   float64
#  43  BusinessType                 967805 non-null  object
#  44  OriginatingLenderLocationID  968527 non-null  int64
#  45  OriginatingLender            968527 non-null  object
#  46  OriginatingLenderCity        968527 non-null  object
#  47  OriginatingLenderState       968527 non-null  object
#  48  Gender                       968527 non-null  object
#  49  Veteran                      968527 non-null  object
#  50  NonProfit                    59339 non-null   object
#  51  ForgivenessAmount            933904 non-null  float64
#  52  ForgivenessDate              933904 non-null  object
# dtypes: float64(13), int64(6), object(34)
# memory usage: 399.0+ MB

# %%
#Adding few more colums to our data frame
df['year'] = pd.DatetimeIndex(df['DateApproved']).year
df['month'] = pd.DatetimeIndex(df['DateApproved']).month
df['ForgivenessYear'] = pd.DatetimeIndex(df['ForgivenessDate']).year
df['ForgivenessMonth'] = pd.DatetimeIndex(df['ForgivenessDate']).month

# %%
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0           NaN  29150-9662     12/18/2020  Paid in Full    24
# 1           NaN  29420-9000     09/28/2021  Paid in Full    24
# 2           NaN  98112-2922     03/17/2021  Paid in Full    24
# 3           NaN  92407-1740     10/16/2021  Paid in Full    24
# 4           NaN         NaN     08/17/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 0                    100              769358.78              769358.78
# 1                    100              736927.79              736927.79
# 2                    100              691355.00              691355.00
# 3                    100              499871.00              499871.00
# 4                    100              367437.00              367437.00
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 0                0.0           NaN                      19248
# 1                0.0           NaN                      19248
# 2                0.0           NaN                       9551
# 3                0.0           NaN                       9551
# 4                0.0           NaN                      57328
#
#                      ServicingLenderName   ServicingLenderAddress  \
# 0                           Synovus Bank            1148 Broadway
# 1                           Synovus Bank            1148 Broadway
# 2  Bank of America, National Association  100 N Tryon St, Ste 170
# 3  Bank of America, National Association  100 N Tryon St, Ste 170
# 4           The Huntington National Bank            17 S High St.
#
#   ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 0            COLUMBUS                   GA         31901-2429
# 1            COLUMBUS                   GA         31901-2429
# 2           CHARLOTTE                   NC         28202-4024
# 3           CHARLOTTE                   NC         28202-4024
# 4            COLUMBUS                   OH         43215-3413
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 0                   U                N            N
# 1                   U                Y            Y
# 2                   U                N            N
# 3                   U                N            N
# 4                   U                N            N
#
#               BusinessAgeDescription  ...  ProjectZip     CD JobsReported  \
# 0  Existing or more than 2 years old  ...  29150-9662  SC-05         62.0
# 1  Existing or more than 2 years old  ...  29420-9000  SC-06         73.0
# 2    New Business or 2 years or less  ...  98112-2922  WA-07         75.0
# 3    New Business or 2 years or less  ...  92407-1740  CA-08         21.0
# 4                         Unanswered  ...         NaN    NaN         25.0
#
#   NAICSCode                              Race               Ethnicity  \
# 0  325510.0                        Unanswered       Unknown/NotStated
# 1  561730.0                             White       Unknown/NotStated
# 2       NaN                        Unanswered       Unknown/NotStated
# 3  236115.0  American Indian or Alaska Native  Not Hispanic or Latino
# 4  484210.0                        Unanswered       Unknown/NotStated
#
#    UTILITIES_PROCEED PAYROLL_PROCEED MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  \
# 0                NaN       769358.78                       NaN           NaN
# 1                NaN       736927.79                       NaN           NaN
# 2                NaN       691355.00                       NaN           NaN
# 3                NaN       499871.00                       NaN           NaN
# 4                NaN       367437.00                       NaN           NaN
#
#    REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 0                     NaN                  NaN                    NaN
# 1                     NaN                  NaN                    NaN
# 2                     NaN                  NaN                    NaN
# 3                     NaN                  NaN                    NaN
# 4                     NaN                  NaN                    NaN
#
#               BusinessType  OriginatingLenderLocationID  \
# 0              Corporation                        19248
# 1      Sole Proprietorship                        19248
# 2  Non-Profit Organization                         9551
# 3              Corporation                         9551
# 4                      NaN                        57328
#
#                        OriginatingLender OriginatingLenderCity  \
# 0                           Synovus Bank              COLUMBUS
# 1                           Synovus Bank              COLUMBUS
# 2  Bank of America, National Association             CHARLOTTE
# 3  Bank of America, National Association             CHARLOTTE
# 4           The Huntington National Bank              COLUMBUS
#
#    OriginatingLenderState      Gender      Veteran NonProfit  \
# 0                      GA  Unanswered   Unanswered       NaN
# 1                      GA  Male Owned  Non-Veteran       NaN
# 2                      NC  Unanswered   Unanswered         Y
# 3                      NC  Male Owned  Non-Veteran       NaN
# 4                      OH  Unanswered   Unanswered       NaN
#
#   ForgivenessAmount ForgivenessDate  year  month ForgivenessYear  \
# 0         773553.37      11/20/2020  2020      5          2020.0
# 1         746336.24      08/12/2021  2020      5          2021.0
# 2         696677.49      02/10/2021  2020      5          2021.0
# 3         395264.11      09/10/2021  2020      5          2021.0
# 4         370819.35      04/08/2021  2020      5          2021.0
#
#    ForgivenessMonth
# 0              11.0
# 1               8.0
# 2               2.0
# 3               9.0
# 4               4.0
#
# [5 rows x 57 columns]

# %%
Firstround = df.loc[df['ProcessingMethod'] == 'PPP']

# %%
Firstround.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  9547507704   05/01/2020            464              PPP
# 1  9777677704   05/01/2020            464              PPP
# 2  5791407702   05/01/2020           1013              PPP
# 3  6223567700   05/01/2020            920              PPP
# 4  9662437702   05/01/2020            101              PPP
#
#                BorrowerName        BorrowerAddress      BorrowerCity  \
# 0     SUMTER COATINGS, INC.  2410 Highway 15 South            Sumter
# 1     PLEASANT PLACES, INC.    7684 Southrail Road  North Charleston
# 2   BOYER CHILDREN'S CLINIC       1850 BOYER AVE E           SEATTLE
# 3  KIRTLEY CONSTRUCTION INC   1661 MARTIN RANCH RD    SAN BERNARDINO
# 4              AERO BOX LLC                    NaN               NaN
#
#   BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0           NaN  29150-9662     12/18/2020  Paid in Full    24
# 1           NaN  29420-9000     09/28/2021  Paid in Full    24
# 2           NaN  98112-2922     03/17/2021  Paid in Full    24
# 3           NaN  92407-1740     10/16/2021  Paid in Full    24
# 4           NaN         NaN     08/17/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 0                    100              769358.78              769358.78
# 1                    100              736927.79              736927.79
# 2                    100              691355.00              691355.00
# 3                    100              499871.00              499871.00
# 4                    100              367437.00              367437.00
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 0                0.0           NaN                      19248
# 1                0.0           NaN                      19248
# 2                0.0           NaN                       9551
# 3                0.0           NaN                       9551
# 4                0.0           NaN                      57328
#
#                      ServicingLenderName   ServicingLenderAddress  \
# 0                           Synovus Bank            1148 Broadway
# 1                           Synovus Bank            1148 Broadway
# 2  Bank of America, National Association  100 N Tryon St, Ste 170
# 3  Bank of America, National Association  100 N Tryon St, Ste 170
# 4           The Huntington National Bank            17 S High St.
#
#   ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 0            COLUMBUS                   GA         31901-2429
# 1            COLUMBUS                   GA         31901-2429
# 2           CHARLOTTE                   NC         28202-4024
# 3           CHARLOTTE                   NC         28202-4024
# 4            COLUMBUS                   OH         43215-3413
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 0                   U                N            N
# 1                   U                Y            Y
# 2                   U                N            N
# 3                   U                N            N
# 4                   U                N            N
#
#               BusinessAgeDescription  ...  ProjectZip     CD JobsReported  \
# 0  Existing or more than 2 years old  ...  29150-9662  SC-05         62.0
# 1  Existing or more than 2 years old  ...  29420-9000  SC-06         73.0
# 2    New Business or 2 years or less  ...  98112-2922  WA-07         75.0
# 3    New Business or 2 years or less  ...  92407-1740  CA-08         21.0
# 4                         Unanswered  ...         NaN    NaN         25.0
#
#   NAICSCode                              Race               Ethnicity  \
# 0  325510.0                        Unanswered       Unknown/NotStated
# 1  561730.0                             White       Unknown/NotStated
# 2       NaN                        Unanswered       Unknown/NotStated
# 3  236115.0  American Indian or Alaska Native  Not Hispanic or Latino
# 4  484210.0                        Unanswered       Unknown/NotStated
#
#    UTILITIES_PROCEED PAYROLL_PROCEED MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  \
# 0                NaN       769358.78                       NaN           NaN
# 1                NaN       736927.79                       NaN           NaN
# 2                NaN       691355.00                       NaN           NaN
# 3                NaN       499871.00                       NaN           NaN
# 4                NaN       367437.00                       NaN           NaN
#
#    REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 0                     NaN                  NaN                    NaN
# 1                     NaN                  NaN                    NaN
# 2                     NaN                  NaN                    NaN
# 3                     NaN                  NaN                    NaN
# 4                     NaN                  NaN                    NaN
#
#               BusinessType  OriginatingLenderLocationID  \
# 0              Corporation                        19248
# 1      Sole Proprietorship                        19248
# 2  Non-Profit Organization                         9551
# 3              Corporation                         9551
# 4                      NaN                        57328
#
#                        OriginatingLender OriginatingLenderCity  \
# 0                           Synovus Bank              COLUMBUS
# 1                           Synovus Bank              COLUMBUS
# 2  Bank of America, National Association             CHARLOTTE
# 3  Bank of America, National Association             CHARLOTTE
# 4           The Huntington National Bank              COLUMBUS
#
#    OriginatingLenderState      Gender      Veteran NonProfit  \
# 0                      GA  Unanswered   Unanswered       NaN
# 1                      GA  Male Owned  Non-Veteran       NaN
# 2                      NC  Unanswered   Unanswered         Y
# 3                      NC  Male Owned  Non-Veteran       NaN
# 4                      OH  Unanswered   Unanswered       NaN
#
#   ForgivenessAmount ForgivenessDate  year  month ForgivenessYear  \
# 0         773553.37      11/20/2020  2020      5          2020.0
# 1         746336.24      08/12/2021  2020      5          2021.0
# 2         696677.49      02/10/2021  2020      5          2021.0
# 3         395264.11      09/10/2021  2020      5          2021.0
# 4         370819.35      04/08/2021  2020      5          2021.0
#
#    ForgivenessMonth
# 0              11.0
# 1               8.0
# 2               2.0
# 3               9.0
# 4               4.0
#
# [5 rows x 57 columns]

# %%
Secondround = df.loc[df['ProcessingMethod'] == 'PPS']

# %%
Secondround.head()
# Out:
#     LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 80  1305708310   01/16/2021           1084              PPS
# 81  1528398702   03/27/2021           1084              PPS
# 82  2340468702   03/28/2021           1084              PPS
# 83  2524238501   02/20/2021           1084              PPS
# 84  3041178300   01/21/2021           1084              PPS
#
#                               BorrowerName      BorrowerAddress BorrowerCity  \
# 80            FOUNTAINHEAD DEVELOPMENT INC      1501 Queens Way    Fairbanks
# 81            NORTHERN ENERGY SERVICES LLC    6250 S Airpark Pl    Anchorage
# 82                    WHITTIER SEAFOOD LLC    375 E WHITTIER ST     WHITTIER
# 83    ALCAN ELECTRICAL AND ENGINEERING INC  6670 Arctic Spur Rd    Anchorage
# 84  FAMILY CENTERED SERVICES OF ALASKA INC       1825 Marika Rd    Fairbanks
#
#    BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 80            AK  99701-7456     03/10/2022  Paid in Full    60
# 81            AK  99502-1865            NaN   Exemption 4    60
# 82            AK       99693            NaN   Exemption 4    60
# 83            AK  99518-1548     10/13/2021  Paid in Full    60
# 84            AK  99709-5521     04/08/2022  Paid in Full    60
#
#     SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 80                    100              2000000.0              2000000.0
# 81                    100              2000000.0              2000000.0
# 82                    100              2000000.0              2000000.0
# 83                    100              2000000.0              2000000.0
# 84                    100              2000000.0              2000000.0
#
#     UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 80                0.0           NaN                       3495
# 81                0.0           NaN                     116975
# 82                0.0           NaN                       9551
# 83                0.0           NaN                     116975
# 84                0.0           NaN                     116975
#
#                       ServicingLenderName   ServicingLenderAddress  \
# 80                      Denali State Bank         119 N Cushman St
# 81                          Northrim Bank              3111 'C' St
# 82  Bank of America, National Association  100 N Tryon St, Ste 170
# 83                          Northrim Bank              3111 'C' St
# 84                          Northrim Bank              3111 'C' St
#
#    ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 80           FAIRBANKS                   AK         99701-2879
# 81           ANCHORAGE                   AK              99503
# 82           CHARLOTTE                   NC         28202-4024
# 83           ANCHORAGE                   AK              99503
# 84           ANCHORAGE                   AK              99503
#
#    RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 80                   R                Y            N
# 81                   U                N            N
# 82                   R                N            N
# 83                   U                N            N
# 84                   R                N            N
#
#                BusinessAgeDescription  ...  ProjectZip   CD JobsReported  \
# 80  Existing or more than 2 years old  ...  99701-7456  AK-        140.0
# 81  Existing or more than 2 years old  ...  99502-1865  AK-        204.0
# 82  Existing or more than 2 years old  ...       99693  AK-        216.0
# 83  Existing or more than 2 years old  ...  99518-1548  AK-         92.0
# 84  Existing or more than 2 years old  ...  99709-5521  AK-        169.0
#
#    NAICSCode        Race               Ethnicity  UTILITIES_PROCEED  \
# 80  721110.0  Unanswered       Unknown/NotStated                1.0
# 81  237310.0  Unanswered       Unknown/NotStated                NaN
# 82  114111.0       White  Not Hispanic or Latino                1.0
# 83  238210.0  Unanswered       Unknown/NotStated                1.0
# 84  624190.0  Unanswered       Unknown/NotStated                NaN
#
#    PAYROLL_PROCEED MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  \
# 80       1999995.0                       NaN           NaN
# 81       2000000.0                       NaN           NaN
# 82       1999999.0                       NaN           NaN
# 83       1999998.0                       NaN           NaN
# 84       2000000.0                       NaN           NaN
#
#     REFINANCE_EIDL_PROCEED  HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 80                     NaN                  NaN                    NaN
# 81                     NaN                  NaN                    NaN
# 82                     NaN                  NaN                    NaN
# 83                     NaN                  NaN                    NaN
# 84                     NaN                  NaN                    NaN
#
#                        BusinessType  OriginatingLenderLocationID  \
# 80         Subchapter S Corporation                         3495
# 81  Limited  Liability Company(LLC)                       116975
# 82  Limited  Liability Company(LLC)                         9551
# 83         Subchapter S Corporation                       116975
# 84          Non-Profit Organization                       116975
#
#                         OriginatingLender OriginatingLenderCity  \
# 80                      Denali State Bank             FAIRBANKS
# 81                          Northrim Bank             ANCHORAGE
# 82  Bank of America, National Association             CHARLOTTE
# 83                          Northrim Bank             ANCHORAGE
# 84                          Northrim Bank             ANCHORAGE
#
#     OriginatingLenderState      Gender      Veteran NonProfit  \
# 80                      AK  Male Owned   Unanswered       NaN
# 81                      AK  Unanswered   Unanswered       NaN
# 82                      NC  Male Owned  Non-Veteran       NaN
# 83                      AK  Unanswered   Unanswered       NaN
# 84                      AK  Unanswered   Unanswered         Y
#
#    ForgivenessAmount ForgivenessDate  year  month ForgivenessYear  \
# 80        2020666.67      02/02/2022  2021      1          2022.0
# 81               NaN             NaN  2021      3             NaN
# 82               NaN             NaN  2021      3             NaN
# 83        2011342.47      09/20/2021  2021      2          2021.0
# 84        2023068.49      03/28/2022  2021      1          2022.0
#
#     ForgivenessMonth
# 80               2.0
# 81               NaN
# 82               NaN
# 83               9.0
# 84               3.0
#
# [5 rows x 57 columns]

# %% [markdown]
# ## Categorical Variables

# %% [markdown]
# ## Univariable

# %%
sns.countplot(df['ProcessingMethod'])
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ProcessingMethod', ylabel='count'>

# %%
sns.countplot(df['LoanStatus'])
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanStatus', ylabel='count'>

# %%
sns.countplot(df['Ethnicity'])
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %%
plt.figure(figsize=(15,6))
ax = sns.countplot(x='BorrowerState', data= df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40, ha='right')
plt.show()

# %%
plt.figure(figsize=(15,6))
ax = sns.countplot(x='BusinessType', data= df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40, ha='right')
plt.show()

# %% [markdown]
# ## Bivariate

# %%
# plotting ethnicity against loan status
sns.countplot(x= 'Ethnicity' ,hue ='LoanStatus' ,data = df)
# Out:
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %%
#cross tabulation
pd.crosstab(df['BorrowerState'],df['Ethnicity'])
# Out:
# Ethnicity      Hispanic or Latino  Not Hispanic or Latino  Unknown/NotStated
# BorrowerState
# AK                             45                     692               1924
# AL                             49                    3230               7633
# AR                             55                    1524               4278
# AS                              0                       1                 19
# AZ                            451                    3586              11757
# CA                           5880                   36429              88305
# CO                            464                    5059              14220
# CT                            167                    3295               9430
# DC                             97                     910               3392
# DE                             36                     859               2101
# FL                           3221                   11573              45242
# GA                            390                    6763              18679
# GU                              4                     152                287
# HI                             93                    1322               3565
# IA                             70                    3085               5140
# ID                             56                    1041               3319
# IL                            631                   10380              29803
# IN                             97                    4979              11524
# KS                             71                    2339               5792
# KY                             59                    2593               6526
# LA                            152                    3045              10471
# MA                            437                    8203              18833
# MD                            247                    4410              14321
# ME                             16                    1144               3025
# MI                            196                    7879              21726
# MN                            149                    6580              12999
# MO                            119                    4778              11453
# MP                              2                      32                 48
# MS                             33                    2012               3457
# MT                             11                    1093               2040
# NC                            168                    3953              18707
# ND                             23                    1412               1787
# NE                             55                    2136               3613
# NH                             34                    1392               3652
# NJ                            519                    7012              25004
# NM                            471                     964               3049
# NV                            278                    2176               5807
# NY                           1229                   17513              55366
# OH                            237                   11843              20566
# OK                            127                    2669               7201
# OR                            196                    3251              10008
# PA                            231                    9977              28327
# PR                            995                      42               1915
# RI                             79                    1268               2445
# SC                             48                    2150               8544
# SD                              8                     874               1813
# TN                            114                    3390              12365
# TX                           3979                   18817              53388
# UT                            149                    2635               6510
# VA                            326                    4708              18234
# VI                              8                      87                195
# VT                              6                     556               1707
# WA                            409                    6047              17298
# WI                            103                    5062              12188
# WV                             26                    1020               2319
# WY                             26                     641               1472

# %%
pd.crosstab(df['year'],df['Ethnicity'])
# Out:
# Ethnicity  Hispanic or Latino  Not Hispanic or Latino  Unknown/NotStated
# year
# 2020                    13123                  150672             495651
# 2021                    10019                   99912             199150

# %% [markdown]
# ## Numerical Variables -Discrete Variable

# %%
df['CurrentApprovalAmount'].describe()
# Out:
# count    9.685270e+05
# mean     5.306225e+05
# std      7.378884e+05
# min      1.500000e+05
# 25%      2.004000e+05
# 50%      2.950000e+05
# 75%      5.393819e+05
# max      1.000000e+07
# Name: CurrentApprovalAmount, dtype: float64

# %% [markdown]
# ### Outliers

# %%
sns.boxplot(df['CurrentApprovalAmount'])
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='CurrentApprovalAmount'>

# %%
plt.figure(figsize =(15,6))
sns.boxplot(x ="LoanStatus",y = 'CurrentApprovalAmount',data =df)
# Out:
# <AxesSubplot:xlabel='LoanStatus', ylabel='CurrentApprovalAmount'>

# %%
sns.distplot(df['CurrentApprovalAmount']/10**3)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CurrentApprovalAmount', ylabel='Density'>

# %%
df['CurrentApprovalAmount'].skew()
# Out:
# 5.75914463155794

# %%
df['CurrentApprovalAmount'].kurt()
# Out:
# 48.97385320083703

# %%
matrix =df.corr()

# %%
f,ax = plt.subplots(figsize = (15,11))
sns.heatmap(matrix, annot = True)
# Out:
# <AxesSubplot:>
